# %%
import xarray as xr

with xr.open_dataset("/Users/anora/Library/CloudStorage/Dropbox-TeamMG/Wanru Wu/Cloudseeding_Anora/SSF/raw/terra/CERES_SSF_Terra-XTRK_Edition4A_Subset_2010010101-2010021513.nc") as ds:
    ds

ds
# Out:
# <xarray.Dataset> Size: 2GB
# Dimensions:                                                        (
#                                                                     time: 3766569,
#                                                                     The_8_most_prevalent_surface_types: 8,
#                                                                     Conditions_clear__lower__upper__upper_over_lower: 4,
#                                                                     Lower_and_Upper_Cloud_Layers: 2)
# Coordinates:
#   * time                                                           (time) datetime64[ns] 30MB ...
# Dimensions without coordinates: The_8_most_prevalent_surface_types,
#                                 Conditions_clear__lower__upper__upper_over_lower,
#                                 Lower_and_Upper_Cloud_Layers
# Data variables: (12/86)
#     lon                                                            (time) float32 15MB ...
# ...

# %%
df_temp
# Out:
#    CERES_SW_TOA_flux___upwards  CERES_SW_radiance___upwards  \
# 0                   242.084726                    81.255253
# 1                   300.316278                    57.600543
# 2                   260.967182                    61.124010
# 3                   240.709114                    93.303697
# 4                   198.279180                    16.393245
# 5                   276.062940                    17.841637
# 6                   203.155524                    11.819656
# 7                   362.120550                    84.935786
# 8                   387.281966                    80.034108
# 9                   184.204532                    88.301093
#
#    CERES_net_SW_surface_flux___Model_B  CERES_solar_zenith_at_surface
# 0                           292.516420                      31.746673
# 1                           229.705497                      92.908043
# 2                           111.517777                      54.738040
# ...

# %%
 # set CERES_SW_TOA_flux___upwards and CERES_SW_radiance___upwards to NaN if zero
cols = ["CERES_SW_TOA_flux___upwards",
        "CERES_SW_radiance___upwards",
        "CERES_net_SW_surface_flux___Model_B",
        "CERES_solar_zenith_at_surface"]
df_temp.loc[df_temp["CERES_solar_zenith_at_surface"] > 90, cols] = np.nan

# %%
df_temp
# Out:
#    CERES_SW_TOA_flux___upwards  CERES_SW_radiance___upwards  \
# 0                   242.084726                    81.255253
# 1                          NaN                          NaN
# 2                   260.967182                    61.124010
# 3                   240.709114                    93.303697
# 4                   198.279180                    16.393245
# 5                   276.062940                    17.841637
# 6                   203.155524                    11.819656
# 7                   362.120550                    84.935786
# 8                          NaN                          NaN
# 9                   184.204532                    88.301093
#
#    CERES_net_SW_surface_flux___Model_B  CERES_solar_zenith_at_surface
# 0                           292.516420                      31.746673
# 1                                  NaN                            NaN
# 2                           111.517777                      54.738040
# ...

# %%
# convert degrees to radians
df_temp['solar_radian'] = df_temp['CERES_solar_zenith_at_surface']/90
df_temp['cos_solar'] = np.cos(df_temp['solar_radian']*0.5*math.pi)

zenith_col = "CERES_solar_zenith_at_surface"
df_temp['cos_zenith_2'] = np.cos(np.deg2rad(df_temp[zenith_col]))

# create normalized versions
for c in cols:
    df_temp[c + "_norm"] = df_temp[c] / df_temp['cos_solar']

df_temp
# Out:
#    CERES_SW_TOA_flux___upwards  CERES_SW_radiance___upwards  \
# 0                   242.084726                    81.255253
# 1                          NaN                          NaN
# 2                   260.967182                    61.124010
# 3                   240.709114                    93.303697
# 4                   198.279180                    16.393245
# 5                   276.062940                    17.841637
# 6                   203.155524                    11.819656
# 7                   362.120550                    84.935786
# 8                          NaN                          NaN
# 9                   184.204532                    88.301093
#
#    CERES_net_SW_surface_flux___Model_B  CERES_solar_zenith_at_surface  \
# 0                           292.516420                      31.746673
# 1                                  NaN                            NaN
# 2                           111.517777                      54.738040
# ...

# %%
print(cols[:-1])
# Out:
# ['CERES_SW_TOA_flux___upwards', 'CERES_SW_radiance___upwards', 'CERES_net_SW_surface_flux___Model_B']
